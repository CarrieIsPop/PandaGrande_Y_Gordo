# %% [markdown]
# <a href="https://colab.research.google.com/github/CarrieIsPop/PandaGrande_Y_Gordo/blob/main/PandaGordo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TRABAJANDO CON PANDA

# %%
#IMPORTAR LA LIBRERIA
import pandas as pd

# %%
#AYUDA DE PANDA
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %% [markdown]
# TOMA DE CONTACTOS

# %%
diccionario = [{'a' : 2, 'b' : 4, 'c' : 9}, {'a' : 16, 'b' : 12, 'c' : 19}]
df = pd.DataFrame(diccionario)
df
# Out:
#     a   b   c
# 0   2   4   9
# 1  16  12  19

# %% [markdown]
# SERIES

# %%
#CREAR UNA SERIE
serie = pd.Series([1, 2, 3, 4, 5, 6], index = ('a', 'b', 'c', 'd', 'e', 'f'))
serie
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
#BORRAR SERIES O FILAS
serie2 = serie.drop(['a', 'e'])
serie2
# Out:
# b    2
# c    3
# d    4
# f    6
# dtype: int64

# %%
#SELECCIONAR SERIES O FILAS
serie[['b', 'd']]
# Out:
# b    2
# d    4
# dtype: int64

# %%
#ASIGNACION
serie['b'] = 100
serie
# Out:
# a      1
# b    100
# c      3
# d      4
# e      5
# f      6
# dtype: int64

# %%
#OPERADORES
serie4 = serie + serie2
serie4
# Out:
# a      NaN
# b    102.0
# c      6.0
# d      8.0
# e      NaN
# f     12.0
# dtype: float64

# %%
#MULTIPLICACION
serie4 = serie4.mul(serie, serie2)
serie4
# Out:
# a        NaN
# b    10200.0
# c       18.0
# d       32.0
# e        NaN
# f       72.0
# dtype: float64

# %%
#DIVISION
serie4 = serie4.div(serie, serie2)
serie4
# Out:
# a     NaN
# b    1.02
# c    2.00
# d    2.00
# e     NaN
# f    2.00
# dtype: float64

# %%
#SUMA
serie4 = serie4.add(serie, serie2)
serie4
# Out:
# a        NaN
# b    10400.0
# c       24.0
# d       40.0
# e        NaN
# f       84.0
# dtype: float64

# %%
#RESTA
serie4 = serie4.sub(serie, serie2)
serie4
# Out:
# a    NaN
# b    2.0
# c    3.0
# d    4.0
# e    NaN
# f    6.0
# dtype: float64

# %% [markdown]
# DATAFRAMES

# %%
datos = {'Alumnos' : ['Mario', 'Lucia', 'Juan', 'Eva'], 'Nota' : [10, 9, 8, 7]}
df = pd.DataFrame(datos)
df
# Out:
#   Alumnos  Nota
# 0   Mario    10
# 1   Lucia     9
# 2    Juan     8
# 3     Eva     7

# %%
#CAMBIAR NOTA DE EVA
df = df.set_index('Alumnos')
df.loc['Eva', 'Nota'] = 10
df
# Out:
#          Nota
# Alumnos
# Mario      10
# Lucia       9
# Juan        8
# Eva        10

# %%
#ELIMINAR COLUMNA
df = df.drop('Juan')
df
# Out:
#          Nota
# Alumnos
# Mario      10
# Lucia       9
# Eva        10

# %% [markdown]
# ENTRADA, SALIDA, LECTURA Y ESCRITURA

# %%
#GRABAR UN DATA FRAME
df.to_csv('/content/misDatos.csv', index = False, columns = ['Alumnos', 'Nota'])

# %%
#LEER EL DATAFRAME
mis_datos = pd.read_csv('/content/misDatos.csv', header = None, nrows = 2)
mis_datos
# Out:
#          0     1
# 0  Alumnos  Nota
# 1    Mario    10

# %%
df = pd.read_excel('/content/Lista-de-clientes-con-nombre-y-direccion.xlsx')
df
# Out:
#         ID                   Nombre completo Fecha de nacimiento  \
# 0    C0001            Leandra Anna Malo Alba          1984-12-08
# 1    C0002           Severo Granados Iglesia          1986-08-12
# 2    C0003                 Lucho Andreu Amat          1990-04-16
# 3    C0004  Matías Mauricio Castillo Barrera          1996-12-02
# 4    C0005        Mauricio Guijarro Castelló          1984-05-14
# ..     ...                               ...                 ...
# 994  C0995              Josué Salom González          1978-10-09
# 995  C0996                   Montserrat Tomé          1986-05-22
# 996  C0997              Berta Izaguirre-Coll          1987-01-20
# 997  C0998       Asunción Arnaiz Castellanos          1998-09-03
# 998  C0999                 Nilo Porras Casas          1976-12-05
#
#                 Dirección Localidad y Código postal        Teléfono  \
# 0    7943 S. Fifth Street     Bergenfield, NJ 07621  (598) 451-5865
# ...
